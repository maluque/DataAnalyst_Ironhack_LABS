# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span></li><li><span><a href="#Challenge-1---Import-and-Describe-the-Dataset" data-toc-modified-id="Challenge-1---Import-and-Describe-the-Dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1 - Import and Describe the Dataset</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Explore-the-dataset-with-mathematical-and-visualization-techniques.-What-do-you-find?" data-toc-modified-id="Explore-the-dataset-with-mathematical-and-visualization-techniques.-What-do-you-find?-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Explore the dataset with mathematical and visualization techniques. What do you find?</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-2---Data-Cleaning-and-Transformation" data-toc-modified-id="Challenge-2---Data-Cleaning-and-Transformation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2 - Data Cleaning and Transformation</a></span></li><li><span><a href="#Challenge-3---Data-Preprocessing" data-toc-modified-id="Challenge-3---Data-Preprocessing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3 - Data Preprocessing</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#We-will-use-the-StandardScaler-from-sklearn.preprocessing-and-scale-our-data.-Read-more-about-StandardScaler-here." data-toc-modified-id="We-will-use-the-StandardScaler-from-sklearn.preprocessing-and-scale-our-data.-Read-more-about-StandardScaler-here.-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>We will use the <code>StandardScaler</code> from <code>sklearn.preprocessing</code> and scale our data. Read more about <code>StandardScaler</code> <a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler" target="_blank">here</a>.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-4---Data-Clustering-with-K-Means" data-toc-modified-id="Challenge-4---Data-Clustering-with-K-Means-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Challenge 4 - Data Clustering with K-Means</a></span></li><li><span><a href="#Challenge-5---Data-Clustering-with-DBSCAN" data-toc-modified-id="Challenge-5---Data-Clustering-with-DBSCAN-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Challenge 5 - Data Clustering with DBSCAN</a></span></li><li><span><a href="#Challenge-6---Compare-K-Means-with-DBSCAN" data-toc-modified-id="Challenge-6---Compare-K-Means-with-DBSCAN-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Challenge 6 - Compare K-Means with DBSCAN</a></span></li><li><span><a href="#Bonus-Challenge-2---Changing-K-Means-Number-of-Clusters" data-toc-modified-id="Bonus-Challenge-2---Changing-K-Means-Number-of-Clusters-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Bonus Challenge 2 - Changing K-Means Number of Clusters</a></span></li><li><span><a href="#Bonus-Challenge-3---Changing-DBSCAN-eps-and-min_samples" data-toc-modified-id="Bonus-Challenge-3---Changing-DBSCAN-eps-and-min_samples-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Bonus Challenge 3 - Changing DBSCAN <code>eps</code> and <code>min_samples</code></a></span></li></ul></div>

# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn as sns                              # plotting library
sns.set(style='white')                             # seaborn style


import warnings                                              
from sklearn.exceptions import DataConversionWarning          
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

import dataanalysis_fun1 as mlg

# %% [markdown]
# # Challenge 1 - Import and Describe the Dataset
#
# In this lab, we will use a dataset containing information about customer preferences. We will look at **how much each customer spends in a year** on each subcategory in the grocery store and try to **find similarities using clustering.
#
# The origin of the dataset is [here](https://archive.ics.uci.edu/ml/datasets/wholesale+customers).

# %%
# loading the data:
df = pd.read_csv('../data/Wholesale customers data.csv')

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %% [markdown]
# #### Explore the dataset with mathematical and visualization techniques. What do you find?
#
# Checklist:
#
# * What does each column mean?
# * Any categorical data to convert?
# * Any missing data to remove?
# * Column collinearity - any high correlations?
# * Descriptive statistics - any outliers to remove?
# * Column-wise data distribution - is the distribution skewed?
# * Etc.
#
# Additional info: Over a century ago, an Italian economist named Vilfredo Pareto discovered that roughly 20% of the customers account for 80% of the typical retail sales. This is called the [Pareto principle](https://en.wikipedia.org/wiki/Pareto_principle). Check if this dataset displays this characteristic.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %% [markdown]
# #### categorical variables
#
# These variables are expressed in int64 but represent categorical groups

# %%
df0=df.copy()
df0['Channel'] = df['Channel'].astype("object")
df0['Region'] = df['Region'].astype("object")
mlg.categ_summ(df0)
# Out:
#          count  unique  top  freq  unicount_ratio  resto_abs  resto_per
# Channel    440       2    1   298        0.004545        142  32.272727
# Region     440       3    3   316        0.006818        124  28.181818

# %% [markdown]
# #### descriptive statistics

# %%
col_list= ['Fresh', 'Milk', 'Grocery', 'Frozen',
       'Detergents_Paper', 'Delicassen']

# %%
plt.rcParams['xtick.labelsize'] = 'medium'

df[col_list].hist(figsize=(6, 6), bins=50)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))  
sns.boxplot(data=df[col_list], palette="husl")
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show();

# %%
df[col_list].describe().T
# Out:
#                   count          mean           std   min      25%     50%  \
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicassen        440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%       max
# Fresh             16933.75  112151.0
# Milk               7190.25   73498.0
# Grocery           10655.75   92780.0
# Frozen             3554.25   60869.0
# Detergents_Paper   3922.00   40827.0
# Delicassen         1820.25   47943.0

# %% [markdown]
# #### Drop outliers ---> df1

# %%
3 * df[col_list].describe().T["std"][1]
# Out:
# 22141.131523712527

# %%
df1=df.copy()
for col in col_list:
    # Calculate the threshold (3 times the standard deviation)
    THR = 2.5 * df[col].std()
    # Filter rows where the absolute difference from the mean is within the threshold
    df1 = df1[abs(df1[col] - df1[col].mean()) < THR]
    
f'We droped {len(df) - len(df1)} rows with outliers (point - mean 3 times the std)'
# Out:
# 'We droped 39 rows with outliers (point - mean 3 times the std)'

# %%
plt.figure(figsize=(6, 5))  
sns.boxplot(data=df1[col_list], palette="husl")
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show();

# %%
plt.rcParams['xtick.labelsize'] = 'medium'

df1[col_list].hist(figsize=(6, 6), bins=50)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### colinearity

# %%
plt.figure(figsize=(6, 6))   # 150x100 pixeles

sns.set(style='white')    # estilo blanco

mask=np.triu(np.ones_like(df1[col_list].corr(), dtype=bool))    # mascara para tapar lo de arriba

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de  colores


sns.heatmap(df1[col_list].corr(),    
            mask=mask,
            cmap=cmap,
            center=0,
            square=True,
            annot=True,
            linewidths=0.5,
            cbar_kws={'shrink': 0.5});

# %% [markdown]
# **Your observations here**
#
# + `Channel` and `Region` are classified by number_ids,
#     so these variables are considered int64 but they are **categorical variables actually**
# + There are NO NAN'S
# + There are multiple outliers - I will take out data **points - mean > 2.5 x standard dev**.
# + Even excluding outliers, the distributions are **skewed following a negative exponential curve**
# + Some variables reveal colinearity e.g., **Grocery & Detergents_paper** // **Milk & Grocery**

# %% [markdown]
# #### Evaluate if roughly 20% of the customers account for 80% of the typical retail sales

# %%
# cumulative column
cumul_df=df1[col_list]
cumul_df["total"] = df1[col_list].sum(axis=1)
cumul_df=cumul_df.sort_values(by=["total"])
cumul_df['acum'] = cumul_df['total'].cumsum()
cumul_df=cumul_df.reset_index()
# Out:
# /Users/Marina/anaconda3/envs/env37/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
cumul_df.tail()
# Out:
#      index  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 396    331  11223  14881    26839    1234              9606        1102
# 397     28   4113  20484    25957    1158              8604        5206
# 398     77  12205  12697    28540     869             12034        1009
# 399     49   4967  21412    28921    1798             13583        1163
# 400    435  29703  12051    16027   13135               182        2204
#
#      total      acum
# 396  64885  10809704
# 397  65522  10875226
# 398  67354  10942580
# 399  71844  11014424
# 400  73302  11087726

# %% [markdown]
# #### total sales

# %%
total=cumul_df.iloc[-1]["acum"] # total sales
total
# Out:
# 11087726

# %% [markdown]
# #### minimum sale of the top 20% of customers

# %%
top20=int(round(401*0.20, ndigits=0)) #20% top customers
cumul_df.iloc[-top20:]["total"] # 39485
# Out:
# 321    39485
# 322    39777
# 323    39888
# 324    40499
# 325    41145
#        ...
# 396    64885
# 397    65522
# 398    67354
# 399    71844
# 400    73302
# Name: total, Length: 80, dtype: int64

# %%
0.8*total # 80% of total sales 
min(cumul_df[cumul_df["acum"]> 0.8*total].index) # number of clients I need to overcome that number of sales

f'I need the {round((361 * 100) / 401, ndigits=2)}% of clients, to make the 80 % of total sales'
# Out:
# 'I need the 90.02% of clients, to make the 80 % of total sales'

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 2))     # figura de 1 fila y 3 columnas

plt.figure(figsize=(4, 4))
ax[0].plot(cumul_df.index, cumul_df["acum"], marker='.', linestyle='none', markersize=2)
ax[0].axhline(y=0.8*total, color='red', linestyle='--', label='80 % sales')
ax[0].set_ylim(0, max(cumul_df["acum"]) * 1.1)
ax[0].ticklabel_format(style='plain', axis='y')
ax[0].set_xlabel("Customers sorted by sales")
ax[0].set_ylabel('Cumulative sales');

ax[1].hist(cumul_df["total"], bins=50)
ax[1].axvline(x=39485, color='red', linestyle='--', label='top 20% clients')
ax[1].set_xlabel("Total sales")
ax[1].set_ylabel('');

# %% [markdown]
# # Challenge 2 - Data Cleaning and Transformation
#
# If your conclusion from the previous challenge is the data need cleaning/transformation, do it in the cells below. However, if your conclusion is the data need not be cleaned or transformed, feel free to skip this challenge. But if you do choose the latter, please provide rationale.

# %% [markdown]
# **In the case we will normalize and scale the data during the regression analysis, I would not do any other transformation**

# %% [markdown]
# # Challenge 3 - Data Preprocessing
#
# One problem with the dataset is the value ranges are remarkably different across various categories (e.g. `Fresh` and `Grocery` compared to `Detergents_Paper` and `Delicassen`). If you made this observation in the first challenge, you've done a great job! This means you not only completed the bonus questions in the previous Supervised Learning lab but also researched deep into [*feature scaling*](https://en.wikipedia.org/wiki/Feature_scaling). Keep on the good work!
#
# Diverse value ranges in different features could cause issues in our clustering. The way to reduce the problem is through feature scaling. We'll use this technique again with this dataset.
#
# #### We will use the `StandardScaler` from `sklearn.preprocessing` and scale our data. Read more about `StandardScaler` [here](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler).
#
# *After scaling your data, assign the transformed data to a new variable `customers_scale`.*

# %%
df
# Out:
#     Channel Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0         2      3  12669   9656     7561     214              2674
# 1         2      3   7057   9810     9568    1762              3293
# 2         2      3   6353   8808     7684    2405              3516
# 3         1      3  13265   1196     4221    6404               507
# 4         2      3  22615   5410     7198    3915              1777
# ..      ...    ...    ...    ...      ...     ...               ...
# 435       1      3  29703  12051    16027   13135               182
# 436       1      3  39228   1431      764    4510                93
# 437       2      3  14531  15488    30243     437             14841
# 438       1      3  10290   1981     2232    1038               168
# 439       1      3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# ...

# %%
from sklearn.preprocessing import RobustScaler

# Your code here:
transformer = RobustScaler().fit(df1) #fit the scaler on training data
df_transf=transformer.transform(df1) # scale the data

# %%
df_transf=pd.DataFrame(df_transf, columns=df1.columns)

# %%
plt.rcParams['xtick.labelsize'] = 'medium'

df_transf.hist(figsize=(6, 6), bins=50)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DATA SCALING
# **`StandardScaler` and `RobustScaler`** techniques used for **feature (column) scaling** in machine learning.
#
# * **StandardScaler**: It assumes that the data is normally distributed and is **sensitive to outliers** (scales based on mean)
# * **RobustScaler**: Is **robust to outliers** (scales based on median and interquartile range (IQR))
#
# **`Normalizer`** (available in from `sklearn.preprocessing` too) used for **row-wise normalization**
#
# It Scales each sample (row) independently to have a unit norm (Euclidean norm of 1).
# Does not center the data. Useful for algorithms that require normalized input vectors, like clustering algorithms or neural networks.
#
# * **L1 normalization (Least Absolute Deviations)** scales each feature by dividing it by the sum of its absolute values.
# * **L2 normalization (Least Squares)** scales each feature by dividing it by the square root of the sum of its squares.
#
#
#
# #### USE OR NOT USE ???
#
# In most cases, you **wouldn't use Normalizer directly for linear regression** because linear regression algorithms often **don't require normalized input** features. The regression coefficients (weights) are estimated using the least squares method, which inherently handles feature scales.
#
# If you're using **regularization** techniques like **Ridge or Lasso** regression, which **penalize large coefficients**. In such cases, using **StandardScaler or RobustScaler might be more appropriate**.

# %% [markdown]
# # Challenge 4 - Data Clustering with K-Means
#
# Now let's cluster the data with K-Means first. Initiate the K-Means model, then fit your scaled data. In the data returned from the `.fit` method, there is an attribute called `labels_` which is the cluster number assigned to each data record. What you can do is to assign these labels back to `customers` in a new column called `customers['labels']`. Then you'll see the cluster results of the original data.

# %%
df_transf_clust=df_transf.copy()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)  # init kmeans model with 4 clusters (k)
kmeans_clust = kmeans.fit(df_transf)

# %% [markdown]
# Count the values in `labels`.

# %% [markdown]
# # Challenge 5 - Data Clustering with DBSCAN
#
# Now let's cluster the data using DBSCAN. Use `DBSCAN(eps=0.5)` to initiate the model, then fit your scaled data. In the data returned from the `.fit` method, assign the `labels_` back to `customers['labels_DBSCAN']`. Now your original data have two labels, one from K-Means and the other from DBSCAN.

# %%
from sklearn.cluster import DBSCAN 

dbscan=DBSCAN(eps=0.5) # init DBSCAN model with eps 5
DBSCAN_clust = dbscan.fit(df_transf)


df_transf_clust["KMEANS_4"]=kmeans_clust.labels_
df_transf_clust["DBSCAN_05"]=DBSCAN_clust.labels_

# %% [markdown]
# Count the values in `labels_DBSCAN`.

# %%
len(df_transf_clust["KMEANS_4"].value_counts()), len(df_transf_clust["DBSCAN_05"].value_counts())
# Out:
# (4, 2)

# %% [markdown]
# # Challenge 6 - Compare K-Means with DBSCAN
#
# Now we want to visually compare how K-Means and DBSCAN have clustered our data. We will create scatter plots for several columns. For each of the following column pairs, plot a scatter plot using `labels` and another using `labels_DBSCAN`. Put them side by side to compare. Which clustering algorithm makes better sense?
#
# Columns to visualize:
#
# * `Detergents_Paper` as X and `Milk` as y
# * `Grocery` as X and `Fresh` as y
# * `Frozen` as X and `Delicassen` as y

# %% [markdown]
# Visualize `Detergents_Paper` as X and `Milk` as y by `labels` and `labels_DBSCAN` respectively

# %%
np_transf_clust=np.array(df_transf_clust)

# %%
col_list_all=list()
for index, column_name in enumerate(df_transf_clust.columns):
    col_list_all.append(column_name)
    print(index, column_name)
# Out:
# 0 Channel
# 1 Region
# 2 Fresh
# 3 Milk
# 4 Grocery
# 5 Frozen
# 6 Detergents_Paper
# 7 Delicassen
# 8 KMEANS_4
# 9 DBSCAN_05

# %%
fig, ax = plt.subplots(2, 3, figsize=(12, 8))



ax[0,0].scatter(np_transf_clust[:,6], np_transf_clust[:,3],  c=np_transf_clust[:,-2], cmap='viridis');
ax[0,0].set_title("K-Means")
ax[0,0].set_xlabel(col_list_all[6])
ax[0,0].set_ylabel(col_list_all[3]);

ax[1,0].scatter(np_transf_clust[:,6], np_transf_clust[:,3],  c=np_transf_clust[:,-1], cmap='viridis');
ax[1,0].set_title("DBSCAN")
ax[1,0].set_xlabel(col_list_all[6])
ax[1,0].set_ylabel(col_list_all[3]);

###

ax[0,1].scatter(np_transf_clust[:,4], np_transf_clust[:,4],  c=np_transf_clust[:,-2], cmap='viridis');
ax[0,1].set_title("K-Means")
ax[0,1].set_xlabel(col_list_all[4])
ax[0,1].set_ylabel(col_list_all[2]);


ax[1,1].scatter(np_transf_clust[:,4], np_transf_clust[:,2],  c=np_transf_clust[:,-1], cmap='viridis');
ax[1,1].set_title("DBSCAN")
ax[1,1].set_xlabel(col_list_all[4])
ax[1,1].set_ylabel(col_list_all[2]);

###

ax[0,2].scatter(np_transf_clust[:,5], np_transf_clust[:,7],  c=np_transf_clust[:,-2], cmap='viridis');
ax[0,2].set_title("K-Means")
ax[0,2].set_xlabel(col_list_all[5])
ax[0,2].set_ylabel(col_list_all[7]);


ax[1,2].scatter(np_transf_clust[:,5], np_transf_clust[:,7],  c=np_transf_clust[:,-1], cmap='viridis');
ax[1,2].set_title("DBSCAN")
ax[1,2].set_xlabel(col_list_all[5])
ax[1,2].set_ylabel(col_list_all[7]);

plt.tight_layout()
plt.show();

# %% [markdown]
# Visualize `Grocery` as X and `Fresh` as y by `labels` and `labels_DBSCAN` respectively

# %% [markdown]
# Visualize `Frozen` as X and `Delicassen` as y by `labels` and `labels_DBSCAN` respectively

# %% [markdown]
# Let's use a groupby to see how the mean differs between the groups. Group `customers` by `labels` and `labels_DBSCAN` respectively and compute the means for all columns.

# %%
AA= df_transf_clust.groupby(["KMEANS_4"]).mean()
AA=AA[col_list]

BB= df_transf_clust.groupby(["DBSCAN_05"]).mean()
BB=BB[col_list]

display(AA)
display(BB)
# Out:
#              Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# KMEANS_4
# 0         0.176566 -0.164401 -0.137842  0.037360          0.029849   -0.131967
# 1        -0.254399  1.291936  1.640217 -0.058859          2.030425    0.239450
# 2         0.521373  0.038449 -0.101335  2.612695         -0.044914    0.424387
# 3         0.530631  0.745199  0.545352  0.155158          0.543257    1.621155
#               Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# DBSCAN_05
# -1         0.264156  0.417637  0.440936  0.504882          0.592836
#  0        -0.016162 -0.343137 -0.320862  0.048529         -0.110931
#
#            Delicassen
# DBSCAN_05
# -1           0.417092
#  0          -0.210448

# %% [markdown]
# Which algorithm appears to perform better?

# %% [markdown]
# **Both methods returned quite different means along clusters. However, based on the scatter plots, I would choose K-means.**

# %% [markdown]
# # Bonus Challenge 2 - Changing K-Means Number of Clusters
#
# As we mentioned earlier, we don't need to worry about the number of clusters with DBSCAN because it automatically decides that based on the parameters we send to it. But with K-Means, we have to supply the `n_clusters` param (if you don't supply `n_clusters`, the algorithm will use `8` by default). You need to know that the optimal number of clusters differs case by case based on the dataset. K-Means can perform badly if the wrong number of clusters is used.
#
# In advanced machine learning, data scientists try different numbers of clusters and evaluate the results with statistical measures (read [here](https://en.wikipedia.org/wiki/Cluster_analysis#External_evaluation)). We are not using statistical measures today but we'll use our eyes instead. In the cells below, experiment with different number of clusters and visualize with scatter plots. What number of clusters seems to work best for K-Means?

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)  # init kmeans model with 4 clusters (k)
kmeans_clust = kmeans.fit(df_transf)


df_transf_clust["KMEANS_3"]=kmeans_clust.labels_

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2)  # init kmeans model with 4 clusters (k)
kmeans_clust = kmeans.fit(df_transf)


df_transf_clust["KMEANS_2"]=kmeans_clust.labels_

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)  # init kmeans model with 4 clusters (k)
kmeans_clust = kmeans.fit(df_transf)


df_transf_clust["KMEANS_5"]=kmeans_clust.labels_

# %%
np_transf_clust=np.array(df_transf_clust)

# %%
np_transf_clust.shape
# Out:
# (401, 13)

# %%
col_list_all=list()
for index, column_name in enumerate(df_transf_clust.columns):
    col_list_all.append(column_name)
    print(index, column_name)
# Out:
# 0 Channel
# 1 Region
# 2 Fresh
# 3 Milk
# 4 Grocery
# 5 Frozen
# 6 Detergents_Paper
# 7 Delicassen
# 8 KMEANS_4
# 9 DBSCAN_05
# 10 KMEANS_3
# 11 KMEANS_2
# 12 KMEANS_5

# %% [markdown]
# * `Detergents_Paper` as X and `Milk` as y  # 6, 3
# * `Grocery` as X and `Fresh` as y # 4, 2
# * `Frozen` as X and `Delicassen` as y # 5, 7

# %%
#df_transf_clust
[index for index, colname in enumerate(col_list_all) if colname == "KMEANS_5"]
#df_transf_clust.columns[-3]
# Out:
# [12]

# %%
np_transf_clust.shape
# Out:
# (401, 10)

# %%
fig, ax = plt.subplots(3, 3, figsize=(12, 8))


ax[0,0].scatter(np_transf_clust[:,6], np_transf_clust[:,3],  c=np_transf_clust[:,12], cmap='viridis');
ax[0,0].set_title("K-Means 5")
ax[0,0].set_xlabel(col_list_all[6])
ax[0,0].set_ylabel(col_list_all[3]);

ax[1,0].scatter(np_transf_clust[:,6], np_transf_clust[:,3],  c=np_transf_clust[:,-3], cmap='viridis');
ax[1,0].set_title("K-Means 3")
ax[1,0].set_xlabel(col_list_all[6])
ax[1,0].set_ylabel(col_list_all[3]);

ax[2,0].scatter(np_transf_clust[:,6], np_transf_clust[:,3],  c=np_transf_clust[:,-2], cmap='viridis');
ax[2,0].set_title("K-Means 2")
ax[2,0].set_xlabel(col_list_all[6])
ax[2,0].set_ylabel(col_list_all[3]);

###

ax[0,1].scatter(np_transf_clust[:,4], np_transf_clust[:,2],  c=np_transf_clust[:,12], cmap='viridis');
ax[0,1].set_title("K-Means 5")
ax[0,1].set_xlabel(col_list_all[4])
ax[0,1].set_ylabel(col_list_all[2]);


ax[1,1].scatter(np_transf_clust[:,4], np_transf_clust[:,2],  c=np_transf_clust[:,-3], cmap='viridis');
ax[1,1].set_title("K-Means 3")
ax[1,1].set_xlabel(col_list_all[4])
ax[1,1].set_ylabel(col_list_all[2]);

ax[2,1].scatter(np_transf_clust[:,4], np_transf_clust[:,2],  c=np_transf_clust[:,-2], cmap='viridis');
ax[2,1].set_title("K-Means 2")
ax[2,1].set_xlabel(col_list_all[4])
ax[2,1].set_ylabel(col_list_all[2]);

###


ax[0,2].scatter(np_transf_clust[:,5], np_transf_clust[:,7],  c=np_transf_clust[:,12], cmap='viridis');
ax[0,2].set_title("K-Means 5")
ax[0,2].set_xlabel(col_list_all[5])
ax[0,2].set_ylabel(col_list_all[7]);


ax[1,2].scatter(np_transf_clust[:,5], np_transf_clust[:,7],  c=np_transf_clust[:,-3], cmap='viridis');
ax[1,2].set_title("K-Means 3")
ax[1,2].set_xlabel(col_list_all[5])
ax[1,2].set_ylabel(col_list_all[7]);

ax[2,2].scatter(np_transf_clust[:,5], np_transf_clust[:,7],  c=np_transf_clust[:,-2], cmap='viridis');
ax[2,2].set_title("K-Means 2")
ax[2,2].set_xlabel(col_list_all[5])
ax[2,2].set_ylabel(col_list_all[7]);

plt.tight_layout()
plt.show();

# %% [markdown]
# **K-means with 2 clusters seems to work best to categorize the data**

# %% [markdown]
# # Bonus Challenge 3 - Changing DBSCAN `eps` and `min_samples`
#
# Experiment changing the `eps` and `min_samples` params for DBSCAN. See how the results differ with scatter plot visualization.

# %%
from sklearn.cluster import DBSCAN 
from sklearn.metrics import silhouette_score

df_transf_clust2=df_transf.copy()

eps_list=np.arange(0.25, 2.5, 0.25)
samp_list=np.arange(10, 15, 1)

silh_scores=list()
for eps_i in eps_list:
    for samp_j in samp_list:
        dbscan=DBSCAN(eps=eps_i, min_samples=samp_j) # init DBSCAN model with eps 5
        DBSCAN_clust = dbscan.fit(df_transf)
        df_transf_clust2[f'DBSCAN_{eps_i}_{samp_j}']=DBSCAN_clust.labels_
        try:
            silh_scores.append(silhouette_score(df_transf, DBSCAN_clust.labels_))
        except:
            silh_scores.append(-1)
            print(eps_i, samp_j)
# Out:
# 0.25 10
# 0.25 11
# 0.25 12
# 0.25 13
# 0.25 14

# %%
len(silh_scores)
# Out:
# 45

# %% [markdown]
# #### Get the last 4 combinations, highest 4 silhouette modules

# %%
best_silh=df_transf_clust2.columns[-4:]

# %%
plt.scatter(np.arange(0, len(silh_scores)), silh_scores);

# %%
# PLOT RANDOM 4 CLUSTERS

# %%
np_transf_clust2=np.array(df_transf_clust2)

fig, ax = plt.subplots(2, 4, figsize=(12, 8))


ax[0,0].scatter(np_transf_clust[:,6], np_transf_clust2[:,3],  c=np_transf_clust2[:,10], cmap='viridis');
ax[0,0].set_title(df_transf_clust2.columns[10])
ax[0,0].set_xlabel(col_list_all[6])
ax[0,0].set_ylabel(col_list_all[3]);

ax[0,1].scatter(np_transf_clust[:,6], np_transf_clust2[:,3],  c=np_transf_clust2[:,-27], cmap='viridis');
ax[0,1].set_title(df_transf_clust2.columns[-27])
ax[0,1].set_xlabel(col_list_all[6])
ax[0,1].set_ylabel(col_list_all[3]);

ax[0,2].scatter(np_transf_clust[:,6], np_transf_clust2[:,3],  c=np_transf_clust2[:,-12], cmap='viridis');
ax[0,2].set_title(df_transf_clust2.columns[-12])
ax[0,2].set_xlabel(col_list_all[6])
ax[0,2].set_ylabel(col_list_all[3]);

ax[0,3].scatter(np_transf_clust[:,6], np_transf_clust2[:,3],  c=np_transf_clust2[:,-4], cmap='viridis');
ax[0,3].set_title(df_transf_clust2.columns[-4])
ax[0,3].set_xlabel(col_list_all[6])
ax[0,3].set_ylabel(col_list_all[3]);


###

ax[1,0].scatter(np_transf_clust[:,5], np_transf_clust2[:,7],  c=np_transf_clust2[:,10], cmap='viridis');
ax[1,0].set_title(df_transf_clust2.columns[10])
ax[1,0].set_xlabel(col_list_all[5])
ax[1,0].set_ylabel(col_list_all[7]);

ax[1,1].scatter(np_transf_clust[:,5], np_transf_clust2[:,7],  c=np_transf_clust2[:,-27], cmap='viridis');
ax[1,1].set_title(df_transf_clust2.columns[-27])
ax[1,1].set_xlabel(col_list_all[5])
ax[1,1].set_ylabel(col_list_all[7]);

ax[1,2].scatter(np_transf_clust[:,5], np_transf_clust2[:,7],  c=np_transf_clust2[:,-12], cmap='viridis');
ax[1,2].set_title(df_transf_clust2.columns[-12])
ax[1,2].set_xlabel(col_list_all[5])
ax[1,2].set_ylabel(col_list_all[7]);

ax[1,3].scatter(np_transf_clust[:,5], np_transf_clust2[:,7],  c=np_transf_clust2[:,-4], cmap='viridis');
ax[1,3].set_title(df_transf_clust2.columns[-4])
ax[1,3].set_xlabel(col_list_all[5])
ax[1,3].set_ylabel(col_list_all[7]);

plt.tight_layout()

# %% [markdown]
# All the clustering models that I evaluated were quite bad (above there is only a sample)
