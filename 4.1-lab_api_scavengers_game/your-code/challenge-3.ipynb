# %% [markdown]
# # Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
#
# After you find out the secrete files:
#
# Sort the filenames ascendingly.
#
# Read the content of each secret files into an array of strings.
#
# Concatenate the strings in the array separating each two with a whitespace.
#
# Print out the joke.

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
import json
import requests as req
from logs.GITpass import GITtok ## my GIT TOKEN
display(len(GITtok)) # to chek if it is loaded
HEADER = {'Authorization': 'token ' + GITtok } 
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents?extension:scavengerhunt'
# Out:
# 40

# %%
response = req.get(url, headers=HEADER)
if response.status_code == 200:
    content = response.content #raw content (bytes)
    text = response.text #raw content (text)
    json_data = response.json() #raw content in JSON format
    print(response)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# <Response [200]>

# %%
json_data[0].keys()
# Out:
# dict_keys(['name', 'path', 'sha', 'size', 'url', 'html_url', 'git_url', 'download_url', 'type', '_links'])

# %%
json_data[1]["html_url"]
# Out:
# 'https://github.com/ironhack-datalabs/scavenger/tree/master/15024'

# %%
[print(json_i["html_url"]) for json_i in json_data[1:10]]
# Out:
# https://github.com/ironhack-datalabs/scavenger/tree/master/15024
# https://github.com/ironhack-datalabs/scavenger/tree/master/15534
# https://github.com/ironhack-datalabs/scavenger/tree/master/17020
# https://github.com/ironhack-datalabs/scavenger/tree/master/30351
# https://github.com/ironhack-datalabs/scavenger/tree/master/40303
# https://github.com/ironhack-datalabs/scavenger/tree/master/44639
# https://github.com/ironhack-datalabs/scavenger/tree/master/45525
# https://github.com/ironhack-datalabs/scavenger/tree/master/47222
# https://github.com/ironhack-datalabs/scavenger/tree/master/47830
# [None, None, None, None, None, None, None, None, None]

# %%
json_data[1]["html_url"]
# Out:
# 'https://github.com/ironhack-datalabs/scavenger/tree/master/15024'

# %%
for json_i in json_data:
    response = req.get(json_i["html_url"], headers=HEADER)
    if response.status_code == 200:
        json_data2 = response.json() #raw content in JSON format
        print(json_data2)
    else:
        print(f"Request failed with status code: {response.status_code}")
# Out:
# {'payload': {'allShortcutsEnabled': False, 'fileTree': {'': {'items': [{'name': '15024', 'path': '15024', 'contentType': 'directory'}, {'name': '15534', 'path': '15534', 'contentType': 'directory'}, {'name': '17020', 'path': '17020', 'contentType': 'directory'}, {'name': '30351', 'path': '30351', 'contentType': 'directory'}, {'name': '40303', 'path': '40303', 'contentType': 'directory'}, {'name': '44639', 'path': '44639', 'contentType': 'directory'}, {'name': '45525', 'path': '45525', 'contentType': 'directory'}, {'name': '47222', 'path': '47222', 'contentType': 'directory'}, {'name': '47830', 'path': '47830', 'contentType': 'directory'}, {'name': '49418', 'path': '49418', 'contentType': 'directory'}, {'name': '50896', 'path': '50896', 'contentType': 'directory'}, {'name': '55417', 'path': '55417', 'contentType': 'directory'}, {'name': '55685', 'path': '55685', 'contentType': 'directory'}, {'name': '60224', 'path': '60224', 'contentType': 'directory'}, {'name': '64880', 'path': '6488
# ...

# %%
json_data2["payload"].keys()
# Out:
# dict_keys(['allShortcutsEnabled', 'path', 'repo', 'currentUser', 'refInfo', 'tree', 'fileTree', 'fileTreeProcessingTime', 'foldersToFetch', 'treeExpanded', 'symbolsExpanded', 'csrf_tokens'])

# %%
json_data2["payload"]["fileTree"][""]["items"][0]["name"]
# Out:
# '15024'
